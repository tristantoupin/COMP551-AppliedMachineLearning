# %% [markdown]
# # 3. Gradient Descent for Regression

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
from collections import deque
import matplotlib.pyplot as plt

# %% [markdown]
# ### Global

# %%
np.random.seed = 12345
datasets_path = "../Datasets/"

# %% [markdown]
# ### Variables

# %%
# Storing data in dataframes, and dropping a random column with unknown values in it, plus renaming the columns
df_train = pd.read_csv(datasets_path + 
                       "Dataset_2_train.csv", 
                       header = None).drop(labels=2, axis=1).rename(index=str, columns={0: "x", 1: "y"})
df_test = pd.read_csv(datasets_path + 
                      "Dataset_2_test.csv", 
                      header = None).drop(labels=2, axis=1).rename(index=str, columns={0: "x", 1: "y"})
df_val = pd.read_csv(datasets_path + 
                     "Dataset_2_valid.csv", 
                     header = None).drop(labels=2, axis=1).rename(index=str, columns={0: "x", 1: "y"})

# %% [markdown]
# ## Part 1

# %%
regression_fn_coeffs = np.random.rand(2)*20
patience = 5  # To measure learning stature
print(np.poly1d(regression_fn_coeffs))
# Out:
#
# 11.78 x + 15.72

# %%
def get_loss(xs, ys, w_i):
    loss = 0
    for x, y in zip(xs,ys):
        loss += (np.polyval(regression_fn_coeffs, x) - y) * (x**(1-w_i))
    return loss/(len(xs))

def compute_mse(xs, ys):
    
    mse = (np.polyval(regression_fn_coeffs, xs) - ys).mean()
    return mse

# %%
def train(df_train, df_val, learning_rate = 1e-6):
    # train and valication data
    xs, ys = df_train.x.values, df_train.x.values
    x_val, y_val = df_val.x.values, df_val.x.values
    
    # rolling window over MSE to stop when stature
    rolling_mse_val = deque(maxlen=patience)
    all_mse_val, all_mse_tr = [], []
    epoch = 0
    
    # Training loop, stoping based on rolling_mse
    while True:

        for c_i, c in enumerate(regression_fn_coeffs):
            # update weights
            regression_fn_coeffs[c_i] -= learning_rate * get_loss(xs, ys, c_i)
        
        # get epoch MSE for validation and train
        current_mse_val, current_mse_tr = compute_mse(x_val, y_val), compute_mse(xs, ys)
        
        # add MSEs to lists
        all_mse_val.append(current_mse_val)
        all_mse_tr.append(current_mse_tr)
        rolling_mse_val.append(current_mse_val)
        
        # evaluate model every 1000 steps and stop if stature
        if epoch % patience == 0 and epoch >= patience:
            print("\nMean Squared Error at epoch %s is %s" % (epoch, current_mse_val))
            print("Polynomial equation at epoch %s is %s" % (epoch, (np.poly1d(regression_fn_coeffs))))
            plot_fcts()
            if sum(rolling_mse_val)/len(rolling_mse_val) < rolling_mse_val[-1]:
                # Not learning anymore, returning all mse
                return all_mse_tr, all_mse_val
        epoch += 1

# %%
all_mse_train, all_mse_val = train(df_train, df_val, 1e-2)
# Out:
# Mean Squared Error at epoch 5 is 328.25750031
# Polynomial equation at epoch 5 is
# 8.682 x + 12.06
# Mean Squared Error at epoch 10 is 278.055815036
# Polynomial equation at epoch 10 is
# 7.953 x + 11.19
# Mean Squared Error at epoch 15 is 235.542820213
# Polynomial equation at epoch 15 is
# 7.283 x + 10.4
# Mean Squared Error at epoch 20 is 199.540814604
# Polynomial equation at epoch 20 is
# 6.667 x + 9.668
# Mean Squared Error at epoch 25 is 169.052491866
# Polynomial equation at epoch 25 is
# 6.1 x + 8.995
# Mean Squared Error at epoch 30 is 143.233308352
# Polynomial equation at epoch 30 is
# 5.58 x + 8.375
# Mean Squared Error at epoch 35 is 121.368083513
# Polynomial equation at epoch 35 is
# 5.101 x + 7.803
# Mean Squared Error at epoch 40 is 102.851184576
# Polynomial equation at epoch 40 is
# 4.662 x + 7.277
# Mean Squared Error at epoch 45 is 87.1697464565
# Polynomial equation at epoch 45 is
# 4.258 x + 6.792
# Mean Squared Error at epoch 50 is 73.8894619882
# ...

# %%
# Blue line is validation data
# Red line is training data
plt.plot(range(len(all_mse_train)), all_mse_train, 'ro', range(len(all_mse_val)), all_mse_val, 'bo')
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.show()

# %% [markdown]
# ## Part 2

# %%
print(np.poly1d(regression_fn_coeffs))
# Out:
#
# 1 x + 2.36e-15

# %%
def plot_fcts():
    
    ys = []
    for x in df_val.x.values:
        ys.append(np.polyval(regression_fn_coeffs, x))


    plt.plot(df_val.x.values, ys, 'ro', df_val.x.values, df_val.y.values, 'bo')
    fig = plt.gcf()
    fig.set_size_inches(18.5, 10.5)
    plt.show()

# %% [markdown]
# ## Part 3

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-cff33b0aa6de> in <module>()
# ----> 1 plot_fcts(regression_fn_coeffs)
#
# TypeError: plot_fcts() takes 0 positional arguments but 1 was given
